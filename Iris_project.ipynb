# %% [markdown]
# <a href="https://colab.research.google.com/github/amnaahsan96-maker/Fast-food-Restaurant-Sales-/blob/main/Iris_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project: Machine Learning
# # Title:"Iris Dataset  "
# ## Model: "LogisticRegression"

# %% [markdown]
# This project focuses on performing data preprocessing, cleaning, and visualization on the well-known Iris dataset. The dataset contains measurements of iris flowers, including sepal length, sepal width, petal length, and petal width, along with their species classification.
#
# The main objective is to prepare the data for analysis by handling missing values, removing inconsistencies, and exploring patterns through visualization techniques. **bold text**

# %% [markdown]
# **importing labraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **The libraries pandas, numpy, and matplotlib.pyplot are imported to perform data analysis and visualization in the project. Pandas is used for handling and organizing the dataset, while NumPy supports numerical computations and array operations. Matplotlib is used to create graphs and visualizations to better understand the data.**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score

# %% [markdown]
# **These libraries are used to split data into training and testing sets, build the Random Forest model, and evaluate its performance using accuracy and other metrics.**

# %% [markdown]
# ## **A- Data inpections**

# %% [markdown]
# **1-checking ist five rows**

# %% [markdown]
# **importing datasets**

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris = pd.DataFrame(data=iris.data, columns=iris.feature_names)
print(iris.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# **2-checking last five**

# %%
iris.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %% [markdown]
# **3-checking details**

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# **5.Checking Rows and Coloumns:**

# %%
iris.shape
# Out:
# (150, 4)

# %% [markdown]
# **5.Column Names**

# %%
iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %% [markdown]
# **7.Data Types for Preprocessing**

# %%
iris.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# dtype: object

# %% [markdown]
# **Label-based Data Selection (row and column)**

# %%
iris.loc[4]
# Out:
# sepal length (cm)    5.0
# sepal width (cm)     3.6
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 4, dtype: float64

# %% [markdown]
# **Applying mathematical fuctions**

# %%
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# # B-Data Cleaning

# %% [markdown]
# **1-checking Missing Values**

# %%
iris.isnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
# [150 rows x 4 columns]

# %%
iris.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %% [markdown]
# 2**."Non-Null Values in Dataset"**

# %%
iris.notnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 True              True               True              True
# 1                 True              True               True              True
# 2                 True              True               True              True
# 3                 True              True               True              True
# 4                 True              True               True              True
# ..                 ...               ...                ...               ...
# 145               True              True               True              True
# 146               True              True               True              True
# 147               True              True               True              True
# 148               True              True               True              True
# 149               True              True               True              True
#
# [150 rows x 4 columns]

# %% [markdown]
# **4.Fill Missing Values**

# %%
iris.interpolate()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# **3.Remove Missing Values**

# %%
iris.dropna()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# **5.Checking Duplicate Records**

# %%
iris.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %% [markdown]
# *6.Removing Duplicate Records** **bold text**

# %%
iris.drop_duplicates()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [149 rows x 4 columns]

# %% [markdown]
# # **C-Numerical functions**

# %% [markdown]
# **1-mean**

# %%
iris.mean(numeric_only=True)
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %% [markdown]
# 2-standard deviation

# %%
iris.std(numeric_only=True)
# Out:
# sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64

# %% [markdown]
# **3-Median**

# %%
iris.median(numeric_only=True)
# Out:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64

# %% [markdown]
# ## Visualization

# %% [markdown]
# **1. Line Plot (Single)**

# %% [markdown]
#  Line Plot
#  Shows trend of sepal length over index

# %%
import matplotlib.pyplot as plt
plt.plot(iris['sepal length (cm)'])
plt.title("Line Plot - Sepal Length")
plt.xlabel("Index")
plt.ylabel("Sepal Length")
plt.show()

# %% [markdown]
# **2. Line Plot (Multiple)**

# %% [markdown]
# **Graph Type: Multiple Line Plot**
# ### **Compares two features on same graph **

# %%
plt.plot(iris['sepal length (cm)'], label='Sepal Length')
plt.plot(iris['sepal width (cm)'], label='Sepal Width')
plt.legend()
plt.title("Multiple Line Plot")
plt.show()

# %% [markdown]
# 3. Bar Plot

# %%
iris.mean().plot(kind='bar')
plt.title("Bar Plot - Average of Features")
plt.ylabel("Mean Value")
plt.show()

# %% [markdown]
# **4. Histogram**

# %% [markdown]
# Graph Type: Histogram
# ➡ Shows distribution of sepal length

# %%
plt.hist(iris['sepal length (cm)'])
plt.title("Histogram - Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **5. Scatter Plot**

# %%
plt.scatter(iris['petal length (cm)'], iris['petal width (cm)'])
plt.title("Scatter Plot - Petal Length vs Petal Width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(iris, hue='species')
plt.show()

# %% [markdown]
# **Heatmap (Correlation)**

# %%
plt.figure(figsize=(8,6))
sns.heatmap(iris.corr(numeric_only=True), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# 8. Box Plot

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=iris)
plt.title("Boxplot of Features")
plt.show()

# %% [markdown]
# **9. Count Plot**

# %%
sns.countplot(x='species', data=iris)
plt.title("Species Count")
plt.show()

# %% [markdown]
# # Model Building (Logistic Regression)

# %% [markdown]
# # 1**. Splitting Features and Target**

# %%
from sklearn.datasets import load_iris

iris_data = load_iris()
iris['species'] = iris_data.target

X = iris.drop('species', axis=1)
y = iris['species']

# %% [markdown]
# **2. Train-Test Split**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# **3. Model Training**

# %%
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %% [markdown]
# **3. Model Training**

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0]

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00

# %% [markdown]
# This project demonstrated how to effectively preprocess, clean, and visualize data using the Iris dataset, followed by building a classification model using Logistic Regression. The dataset was explored, checked for missing values and duplicates, and analyzed statistically to understand feature behavior. Various visualizations using Matplotlib and Seaborn helped reveal relationships and patterns among features. Finally, the machine learning model was trained and evaluated, achieving good performance, which shows that proper data preprocessing and visualization play a crucial role in building accurate and reliable predictive models.
